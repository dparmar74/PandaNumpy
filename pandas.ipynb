# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
df = pd.read_csv('data/olympics_medal_data_1896_2004.csv', skiprows=5)
df
# Out:
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# ...     ...     ...        ...            ...                 ...  ...    ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women
#
# ...

# %%
df.shape
# Out:
# (27174, 11)

# %%
df.head()
# Out:
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3  1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4  1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
#
#    Event Event Gender   Medal  Position
# 0  100km            M    Gold         1
# 1  100km            M  Silver         2
# 2   100m            M  Bronze         3
# 3   100m            M  Bronze         3
# 4   100m            M    Gold         1

# %%
df.tail()
# Out:
#        Year    City    Sport Discipline        Athlete Name  NOC Gender  \
# 27169  2004  Athens  Fencing    Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens  Fencing    Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens  Fencing    Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens  Fencing    Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens  Fencing    Fencing   HEIDEMANN, Britta  GER  Women
#
#            Event Event Gender   Medal  Position
# 27169  épée team            W    Gold         1
# 27170  épée team            W    Gold         1
# 27171  épée team            W  Silver         2
# 27172  épée team            W  Silver         2
# 27173  épée team            W  Silver         2

# %%
df.sample(5)
# Out:
#        Year      City       Sport    Discipline        Athlete Name  NOC  \
# 11535  1964     Tokyo     Cycling  Cycling Road  ANDREOLI, Severino  ITA
# 26290  2004    Athens    Football      Football       TEVEZ, Carlos  ARG
# 26591  2004    Athens  Equestrian      Dressage     SALZGEBER, Ulla  GER
# 1809   1908    London  Gymnastics   Artistic G.      LANDBERG, Sven  SWE
# 15042  1976  Montreal  Gymnastics   Artistic G.       SAADI, Elvira  URS
#
#       Gender             Event Event Gender   Medal  Position
# 11535    Men   team time trial            M  Silver         2
# 26290    Men          football            M    Gold         1
# 26591  Women        individual            X  Silver         2
# 1809     Men  team competition            M    Gold         1
# 15042  Women  team competition            W    Gold         1

# %%
df.describe()
# Out:
#                Year      Position
# count  27174.000000  27174.000000
# mean    1964.685803      1.992566
# std       31.590396      0.817469
# min     1896.000000      1.000000
# 25%     1936.000000      1.000000
# 50%     1972.000000      2.000000
# 75%     1992.000000      3.000000
# max     2004.000000      3.000000

# %%
pd.get_option("display.max_rows")
# Out:
# 60

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['Discipline'])
# Out:
# pandas.core.series.Series

# %%
# what is the range covered for this dataset
df.Year.unique()
# Out:
# array([1896, 1900, 1904, 1908, 1912, 1920, 1924, 1928, 1932, 1936, 1948,
#        1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988, 1992,
#        1996, 2000, 2004])

# %%
df.Year.value_counts()
# Out:
# Year
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1956     885
# 1912     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: count, dtype: int64

# %%
df.Year.value_counts('normalize=true')
# Out:
# Year
# 2000    0.074152
# 2004    0.073526
# 1996    0.068411
# 1992    0.062744
# 1988    0.056893
# 1984    0.053691
# 1980    0.051041
# 1976    0.048024
# 1920    0.047766
# 1972    0.043608
# 1968    0.037941
# 1964    0.037168
# 1952    0.032715
# 1956    0.032568
# 1912    0.032568
# 1924    0.032531
# 1960    0.032457
# 1936    0.032200
# 1948    0.029955
# 1908    0.029587
# 1928    0.026128
# 1932    0.022632
# 1900    0.018842
# 1904    0.017296
# 1896    0.005557
# Name: proportion, dtype: float64

# %%
#types of medal awarded
df.Medal.unique()
# Out:
# array(['Gold', 'Silver', 'Bronze'], dtype=object)

# %%
#how many medal awarded
df.Medal.value_counts()
# Out:
# Medal
# Gold      9181
# Silver    9014
# Bronze    8979
# Name: count, dtype: int64

# %%
mapper = {"Athlete Name":"Athelete_Name",
          "Event Gender":"Event_Gender"}

df.rename(columns=mapper)
# Out:
#        Year    City      Sport     Discipline       Athelete_Name  NOC Gender  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# ...     ...     ...        ...            ...                 ...  ...    ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women
#
# ...

# %%
# drop column
df.drop('Position', axis=1)
# Out:
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# ...     ...     ...        ...            ...                 ...  ...    ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women
#
# ...

# %%
# drop rows
df.drop([1,4,5], axis=0)
# Out:
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 6      1896  Athens   Aquatics       Swimming       HAJOS, Alfred  HUN    Men
# 7      1896  Athens   Aquatics       Swimming    HERSCHMANN, Otto  AUT    Men
# ...     ...     ...        ...            ...                 ...  ...    ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women
#
# ...

# %%
# filter rows
first_olympics= (df.Year == 1896)
df[first_olympics]
# Out:
#      Year    City       Sport     Discipline          Athlete Name  NOC  \
# 0    1896  Athens     Cycling  Cycling Track         FLAMENG, Léon  FRA
# 1    1896  Athens     Cycling  Cycling Track    KOLETTIS, Georgios  GRE
# 2    1896  Athens   Athletics      Athletics         LANE, Francis  USA
# 3    1896  Athens   Athletics      Athletics      SZOKOLYI, Alajos  HUN
# 4    1896  Athens   Athletics      Athletics         BURKE, Thomas  USA
# ..    ...     ...         ...            ...                   ...  ...
# 146  1896  Athens   Athletics      Athletics       CONNOLLY, James  USA
# 147  1896  Athens   Athletics      Athletics    TUFFERI, Alexandre  FRA
# 148  1896  Athens  Gymnastics    Artistic G.  WEINGÄRTNER, Hermann  GER
# 149  1896  Athens  Gymnastics    Artistic G.        SCHUMANN, Carl  GER
# 150  1896  Athens  Gymnastics    Artistic G.         ZUTTER, Louis  SUI
#
#     Gender        Event Event Gender   Medal  Position
# ...

# %%
df[df.City == 'Athens']
# Out:
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# ...     ...     ...        ...            ...                 ...  ...    ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women
#
# ...

# %%
# multiple filter conditions
df[(df.City == 'Athens') & (df.Year == 2004)]
# Out:
#        Year    City          Sport     Discipline           Athlete Name  NOC  \
# 25176  2004  Athens           Judo           Judo      PERTELSON, Indrek  EST
# 25177  2004  Athens           Judo           Judo  VAN DER GEEST, Dennis  NED
# 25178  2004  Athens           Judo           Judo          SUZUKI, Keiji  JPN
# 25179  2004  Athens           Judo           Judo       TMENOV, Tamerlan  RUS
# 25180  2004  Athens  Weightlifting  Weightlifting     CHOLAKOV, Velichko  BUL
# ...     ...     ...            ...            ...                    ...  ...
# 27169  2004  Athens        Fencing        Fencing     LOGOUNOVA, Tatiana  RUS
# 27170  2004  Athens        Fencing        Fencing          SIVKOVA, Anna  RUS
# 27171  2004  Athens        Fencing        Fencing         BOKEL, Claudia  GER
# 27172  2004  Athens        Fencing        Fencing        DUPLITZER, Imke  GER
# 27173  2004  Athens        Fencing        Fencing      HEIDEMANN, Britta  GER
#
# ...

# %%
# filter with specific columns
df[(df.Year == 1896) & (df.Gender == 'Men') & (df.Event == '100m')][['Year', 'Athlete Name', 'Event', 'Medal']]
# Out:
#    Year      Athlete Name Event   Medal
# 2  1896     LANE, Francis  100m  Bronze
# 3  1896  SZOKOLYI, Alajos  100m  Bronze
# 4  1896     BURKE, Thomas  100m    Gold
# 5  1896    HOFMANN, Fritz  100m  Silver

# %%
df['Athlete Name'].str.lower()
# Out:
# 0             flameng, léon
# 1        kolettis, georgios
# 2             lane, francis
# 3          szokolyi, alajos
# 4             burke, thomas
#                 ...
# 27169    logounova, tatiana
# 27170         sivkova, anna
# 27171        bokel, claudia
# 27172       duplitzer, imke
# 27173     heidemann, britta
# Name: Athlete Name, Length: 27174, dtype: object

# %%
#sorting
df['Athlete Name'].sort_values()
# Out:
# 611                 AABYE, Edgar
# 3060       AALTONEN, Arvo Ossian
# 2963       AALTONEN, Arvo Ossian
# 7792    AALTONEN, Paavo Johannes
# 7906    AALTONEN, Paavo Johannes
#                   ...
# 275                   ÖSTMO, Ole
# 443                   ÖSTMO, Ole
# 280                   ÖSTMO, Ole
# 268                   ÖSTMO, Ole
# 8125           ÖSTRAND, Per-Olof
# Name: Athlete Name, Length: 27174, dtype: object

# %%
# sort entire data frame
df.sort_values('Athlete Name')
# Out:
#       Year      City       Sport   Discipline              Athlete Name  NOC  \
# 611   1900     Paris  Tug of War   Tug of War              AABYE, Edgar  ZZX
# 3060  1920   Antwerp    Aquatics     Swimming     AALTONEN, Arvo Ossian  FIN
# 2963  1920   Antwerp    Aquatics     Swimming     AALTONEN, Arvo Ossian  FIN
# 7792  1948    London  Gymnastics  Artistic G.  AALTONEN, Paavo Johannes  FIN
# 7906  1948    London  Gymnastics  Artistic G.  AALTONEN, Paavo Johannes  FIN
# ...    ...       ...         ...          ...                       ...  ...
# 275   1900     Paris    Shooting     Shooting                ÖSTMO, Ole  NOR
# 443   1900     Paris    Shooting     Shooting                ÖSTMO, Ole  NOR
# 280   1900     Paris    Shooting     Shooting                ÖSTMO, Ole  NOR
# 268   1900     Paris    Shooting     Shooting                ÖSTMO, Ole  NOR
# 8125  1952  Helsinki    Aquatics     Swimming         ÖSTRAND, Per-Olof  SWE
#
# ...

# %%
#multi sort
df.sort_values(by=['Year', 'Event', 'Medal'] , ascending=[True, True, False])
# Out:
#        Year    City      Sport     Discipline            Athlete Name  NOC  \
# 1      1896  Athens    Cycling  Cycling Track      KOLETTIS, Georgios  GRE
# 0      1896  Athens    Cycling  Cycling Track           FLAMENG, Léon  FRA
# 5      1896  Athens  Athletics      Athletics          HOFMANN, Fritz  GER
# 4      1896  Athens  Athletics      Athletics           BURKE, Thomas  USA
# 2      1896  Athens  Athletics      Athletics           LANE, Francis  USA
# ...     ...     ...        ...            ...                     ...  ...
# 27154  2004  Athens    Fencing        Fencing         STRIGEL, Daniel  GER
# 27163  2004  Athens    Fencing        Fencing         DANINTHE, Sarah  FRA
# 27164  2004  Athens    Fencing        Fencing  FLESSEL-COLOVIC, Laura  FRA
# 27165  2004  Athens    Fencing        Fencing  KIRALY PICOT, Hajnalka  FRA
# 27166  2004  Athens    Fencing        Fencing         NISIMA, Maureen  FRA
#
#       Gender      Event Event Gender   Medal  Position
# ...

# %%
df.dtypes
# Out:
# Year             int64
# City            object
# Sport           object
# Discipline      object
# Athlete Name    object
# NOC             object
# Gender          object
# Event           object
# Event Gender    object
# Medal           object
# Position         int64
# dtype: object

# %%
df.Medal.astype('category')
# Out:
# 0          Gold
# 1        Silver
# 2        Bronze
# 3        Bronze
# 4          Gold
#           ...
# 27169      Gold
# 27170      Gold
# 27171    Silver
# 27172    Silver
# 27173    Silver
# Name: Medal, Length: 27174, dtype: category
# Categories (3, object): ['Bronze', 'Gold', 'Silver']

# %%
medal_order =['Bronze','Silver', 'Gold' ]
df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

# %%
#memory usage of Object vs Categoriy type. 
new_df = pd.read_csv('data/olympics_medal_data_1896_2004.csv', skiprows=5)
print(f"memory usage using dtype category: {df.Medal.memory_usage(deep=True)}")
print(f"memory usage using dtype object: {new_df.Medal.memory_usage(deep=True)}")
# Out:
# memory usage using dtype category: 27577
# memory usage using dtype object: 1476340

# %%
df.dtypes
# Out:
# Year               int64
# City              object
# Sport             object
# Discipline        object
# Athlete Name      object
# NOC               object
# Gender            object
# Event             object
# Event Gender      object
# Medal           category
# Position           int64
# dtype: object

# %%
# apply dtypes when reading a file
ordered_medal = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver","Gold"], ordered=True)

dtype_mapper = {'Year':'int64',
                'City':'string',
                'Sport':'string',
                'Discipline':'string',
                'Athlete Name':'string',
                'NOC':'string',
                'Gender':'category',
                'Event':'string',
                'Event Gender':'category',
                'Medal':'category',
                'Position':'int64'}

# %%
df1 = pd.read_csv('data/olympics_medal_data_1896_2004.csv', skiprows=5, dtype=dtype_mapper)
df1.dtypes
# Out:
# Year                     int64
# City            string[python]
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender    string[python]
# Medal                 category
# Position                 int64
# dtype: object

# %% [markdown]
# ### Working with Indexes

# %%
df.index
# Out:
# RangeIndex(start=0, stop=27174, step=1)

# %%
df=df.set_index("Athlete Name")
df.index
# Out:
# Index(['FLAMENG, Léon', 'KOLETTIS, Georgios', 'LANE, Francis',
#        'SZOKOLYI, Alajos', 'BURKE, Thomas', 'HOFMANN, Fritz', 'HAJOS, Alfred',
#        'HERSCHMANN, Otto', 'DRIVAS, Dimitrios', 'MALOKINIS, Ioannis',
#        ...
#        'FLESSEL-COLOVIC, Laura', 'KIRALY PICOT, Hajnalka', 'NISIMA, Maureen',
#        'AZNAVOURIAN, Karina', 'ERMAKOVA, Oxana', 'LOGOUNOVA, Tatiana',
#        'SIVKOVA, Anna', 'BOKEL, Claudia', 'DUPLITZER, Imke',
#        'HEIDEMANN, Britta'],
#       dtype='object', name='Athlete Name', length=27174)

# %%
df.loc["LEWIS, Carl", "Event"]
# Out:
# Athlete Name
# LEWIS, Carl            100m
# LEWIS, Carl            200m
# LEWIS, Carl    4x100m relay
# LEWIS, Carl       long jump
# LEWIS, Carl            100m
# LEWIS, Carl            200m
# LEWIS, Carl       long jump
# LEWIS, Carl    4x100m relay
# LEWIS, Carl       long jump
# LEWIS, Carl       long jump
# Name: Event, dtype: object

# %%
df.columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'NOC', 'Gender', 'Event',
#        'Event Gender', 'Medal', 'Position'],
#       dtype='object')

# %%
df.loc["LEWIS, Carl", :]
# Out:
#               Year         City      Sport Discipline  NOC Gender  \
# Athlete Name
# LEWIS, Carl   1984  Los Angeles  Athletics  Athletics  USA    Men
# LEWIS, Carl   1984  Los Angeles  Athletics  Athletics  USA    Men
# LEWIS, Carl   1984  Los Angeles  Athletics  Athletics  USA    Men
# LEWIS, Carl   1984  Los Angeles  Athletics  Athletics  USA    Men
# LEWIS, Carl   1988        Seoul  Athletics  Athletics  USA    Men
# LEWIS, Carl   1988        Seoul  Athletics  Athletics  USA    Men
# LEWIS, Carl   1988        Seoul  Athletics  Athletics  USA    Men
# LEWIS, Carl   1992    Barcelona  Athletics  Athletics  USA    Men
# LEWIS, Carl   1992    Barcelona  Athletics  Athletics  USA    Men
# LEWIS, Carl   1996      Atlanta  Athletics  Athletics  USA    Men
#
#                      Event Event Gender   Medal  Position
# Athlete Name
# LEWIS, Carl           100m            M    Gold         1
# LEWIS, Carl           200m            M    Gold         1
# ...

# %%
# reset index
df.reset_index()
# Out:
#              Athlete Name  Year    City      Sport     Discipline  NOC Gender  \
# 0           FLAMENG, Léon  1896  Athens    Cycling  Cycling Track  FRA    Men
# 1      KOLETTIS, Georgios  1896  Athens    Cycling  Cycling Track  GRE    Men
# 2           LANE, Francis  1896  Athens  Athletics      Athletics  USA    Men
# 3        SZOKOLYI, Alajos  1896  Athens  Athletics      Athletics  HUN    Men
# 4           BURKE, Thomas  1896  Athens  Athletics      Athletics  USA    Men
# ...                   ...   ...     ...        ...            ...  ...    ...
# 27169  LOGOUNOVA, Tatiana  2004  Athens    Fencing        Fencing  RUS  Women
# 27170       SIVKOVA, Anna  2004  Athens    Fencing        Fencing  RUS  Women
# 27171      BOKEL, Claudia  2004  Athens    Fencing        Fencing  GER  Women
# 27172     DUPLITZER, Imke  2004  Athens    Fencing        Fencing  GER  Women
# 27173   HEIDEMANN, Britta  2004  Athens    Fencing        Fencing  GER  Women
#
# ...

# %% [markdown]
# ### Creating Series and DataFrames

# %%
city = ["London", "Rio", "Tokyo"]
start_date = ["27th Jul, 2012", "5th Aug, 2016", "23rd July, 2021"]

# %%
pd.DataFrame({"City": city,
              "Start Date": start_date})
# Out:
#      City       Start Date
# 0  London   27th Jul, 2012
# 1     Rio    5th Aug, 2016
# 2   Tokyo  23rd July, 2021

# %%
pd.DataFrame(zip(city, start_date))
# Out:
#         0                1
# 0  London   27th Jul, 2012
# 1     Rio    5th Aug, 2016
# 2   Tokyo  23rd July, 2021

# %%
pd.DataFrame(zip(city, start_date), columns=["City", "Start Date"])
# Out:
#      City       Start Date
# 0  London   27th Jul, 2012
# 1     Rio    5th Aug, 2016
# 2   Tokyo  23rd July, 2021

# %%
# Working with Dates

# %%
city = ["London", "Rio", "Tokyo"]
start_date = ["07-27-2012", "5th Aug, 2016", "23rd Jul, 2021"]
end_date = ["12th Aug, 2012", "21-08-2016", "8th Aug, 2021"]

# %%
games = pd.DataFrame(zip(city, start_date, end_date), columns=["City", "Start Date", "End Date"])
games
# Out:
#      City      Start Date        End Date
# 0  London      07-27-2012  12th Aug, 2012
# 1     Rio   5th Aug, 2016      21-08-2016
# 2   Tokyo  23rd Jul, 2021   8th Aug, 2021

# %%
games["Start Date"] = pd.to_datetime(games["Start Date"], format='mixed')
games["End Date"] = pd.to_datetime(games["End Date"], format='mixed')
games["City"] = games.City.astype("string")
games
# Out:
#      City Start Date   End Date
# 0  London 2012-07-27 2012-08-12
# 1     Rio 2016-08-05 2016-08-21
# 2   Tokyo 2021-07-23 2021-08-08

# %%
# create a new column
games = games.assign(duration=games["End Date"] - games["Start Date"])
games
# Out:
#      City Start Date   End Date duration
# 0  London 2012-07-27 2012-08-12  16 days
# 1     Rio 2016-08-05 2016-08-21  16 days
# 2   Tokyo 2021-07-23 2021-08-08  16 days

# %% [markdown]
# ### Combining DataFrames

# %%
start = pd.DataFrame({"City": ["London", "Rio", "Tokyo"],
                      "start_date": ["27th Jul, 2012", "5th Aug, 2016", "23rd July, 2021"]})
start
# Out:
#      City       start_date
# 0  London   27th Jul, 2012
# 1     Rio    5th Aug, 2016
# 2   Tokyo  23rd July, 2021

# %%
end = pd.DataFrame({"City": ["London", "Tokyo", "Paris"],
                    "end_date": ["12th Aug, 2012", "8th Aug, 2021", "11th Aug, 2024"]})
end
# Out:
#      City        end_date
# 0  London  12th Aug, 2012
# 1   Tokyo   8th Aug, 2021
# 2   Paris  11th Aug, 2024

# %%
pd.concat([start, end], axis=0)
# Out:
#      City       start_date        end_date
# 0  London   27th Jul, 2012             NaN
# 1     Rio    5th Aug, 2016             NaN
# 2   Tokyo  23rd July, 2021             NaN
# 0  London              NaN  12th Aug, 2012
# 1   Tokyo              NaN   8th Aug, 2021
# 2   Paris              NaN  11th Aug, 2024

# %%
pd.concat([start, end], axis=1)
# Out:
#      City       start_date    City        end_date
# 0  London   27th Jul, 2012  London  12th Aug, 2012
# 1     Rio    5th Aug, 2016   Tokyo   8th Aug, 2021
# 2   Tokyo  23rd July, 2021   Paris  11th Aug, 2024

# %%
# inner join
pd.merge(left=start, right=end, on="City", how="inner")
# Out:
#      City       start_date        end_date
# 0  London   27th Jul, 2012  12th Aug, 2012
# 1   Tokyo  23rd July, 2021   8th Aug, 2021

# %%
# outer  join
pd.merge(left=start, right=end, on="City", how="outer")
# Out:
#      City       start_date        end_date
# 0  London   27th Jul, 2012  12th Aug, 2012
# 1   Paris              NaN  11th Aug, 2024
# 2     Rio    5th Aug, 2016             NaN
# 3   Tokyo  23rd July, 2021   8th Aug, 2021

# %%
# left join
pd.merge(left=start, right=end, on="City", how="left")
# Out:
#      City       start_date        end_date
# 0  London   27th Jul, 2012  12th Aug, 2012
# 1     Rio    5th Aug, 2016             NaN
# 2   Tokyo  23rd July, 2021   8th Aug, 2021

# %%
# Right join
pd.merge(left=start, right=end, on="City", how="right")
# Out:
#      City       start_date        end_date
# 0  London   27th Jul, 2012  12th Aug, 2012
# 1   Tokyo  23rd July, 2021   8th Aug, 2021
# 2   Paris              NaN  11th Aug, 2024

# %% [markdown]
# # Working with missing date

# %%
# loading a new file which has 2008 olympics data and making sure the columns are matching with the previous file
# filling City "na" value 
# filling Year "na" value 

def preprocess_2008(filename="data/olympics_medal_data_1896_2008.csv"):
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  return df

nw_df = preprocess_2008()
nw_df.sample(3)
# Out:
#          City    Year          Sport       Discipline  \
# 1087  Beijing  2008.0       football         Football
# 1567  Beijing  2008.0         rowing           Rowing
# 844   Beijing  2008.0  canoe / kayak  Canoe / Kayak S
#
#                   Athlete Name  NOC Gender                       Event  \
# 1087           ANGERER, Nadine  GER  Women                    football
# 1567  MCKENZIE-MCHARG, Cameron  AUS    Men  four without coxswain (4-)
# 844           LARIONOV, Dmitry  RUS    Men          C-2 (canoe double)
#
#      Event Gender   Medal
# 1087            W  bronze
# 1567            M  silver
# 844             M  bronze

# %%
nw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2059 entries, 0 to 2058
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          2059 non-null   object
#  1   Year          2059 non-null   float64
#  2   Sport         2048 non-null   object
#  3   Discipline    2048 non-null   object
#  4   Athlete Name  2048 non-null   object
#  5   NOC           2048 non-null   object
#  6   Gender        2048 non-null   object
#  7   Event         2048 non-null   object
#  8   Event Gender  2048 non-null   object
#  9   Medal         2048 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 161.0+ KB

# %%
# rows with missing Sport value
nw_df[nw_df.Sport.isna()]
# Out:
#         City    Year Sport Discipline Athlete Name  NOC Gender Event  \
# 62   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 63   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 64   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 65   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 66   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 67   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 68   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 69   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 70   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 220  Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 221  Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
#
#     Event Gender Medal
# 62           NaN   NaN
# 63           NaN   NaN
# 64           NaN   NaN
# 65           NaN   NaN
# ...

# %%
# drop all rows where NaN value for all these specified columns
nw_df = nw_df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")

# check # of entries and non-null count -> should match now.  It means no  "NaN" value in dataframe
nw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2048 entries, 0 to 2058
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          2048 non-null   object
#  1   Year          2048 non-null   float64
#  2   Sport         2048 non-null   object
#  3   Discipline    2048 non-null   object
#  4   Athlete Name  2048 non-null   object
#  5   NOC           2048 non-null   object
#  6   Gender        2048 non-null   object
#  7   Event         2048 non-null   object
#  8   Event Gender  2048 non-null   object
#  9   Medal         2048 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 176.0+ KB

# %% [markdown]
# # Working with Duplicates

# %%
nw_df.duplicated().sum()
# Out:
# np.int64(6)

# %%
nw_df.loc[nw_df.duplicated(), :]
# Out:
#          City    Year      Sport       Discipline    Athlete Name  NOC Gender  \
# 2053  Beijing  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS    Men
# 2054  Beijing  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS    Men
# 2055  Beijing  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS    Men
# 2056  Beijing  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS    Men
# 2057  Beijing  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS    Men
# 2058  Beijing  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS    Men
#
#            Event Event Gender   Medal
# 2053  96 - 120kg            M  silver
# 2054  96 - 120kg            M  silver
# 2055  96 - 120kg            M  silver
# 2056  96 - 120kg            M  silver
# 2057  96 - 120kg            M  silver
# 2058  96 - 120kg            M  silver

# %%
# check duplicate based on some columns
athlete_multiple_events = nw_df.duplicated(subset=['Athlete Name', 'NOC', 'Gender'])
athlete_multiple_events

# shows only duplicated entries
nw_df.loc[athlete_multiple_events, :].sort_values("Athlete Name")
# Out:
#          City    Year         Sport       Discipline          Athlete Name  \
# 489   Beijing  2008.0     athletics        Athletics    ABEYLEGESSE, Elvan
# 239   Beijing  2008.0      aquatics         Swimming    ADLINGTON, Rebecca
# 1595  Beijing  2008.0        rowing           Rowing  ANDRUNACHE, Georgeta
# 2058  Beijing  2008.0     wrestling  Wrestling Gre-R        BAROEV, Khasan
# 2056  Beijing  2008.0     wrestling  Wrestling Gre-R        BAROEV, Khasan
# ...       ...     ...           ...              ...                   ...
# 1024  Beijing  2008.0       fencing          Fencing       ZAGUNIS, Mariel
# 381   Beijing  2008.0       archery          Archery      ZHANG, Juan Juan
# 1793  Beijing  2008.0  table tennis     Table Tennis         ZHANG, Yining
# 1151  Beijing  2008.0    gymnastics      Artistic G.              ZOU, Kai
# 1179  Beijing  2008.0    gymnastics      Artistic G.              ZOU, Kai
#
# ...

# %%
# keep first row, and mark next two rows as duplicate
nw_df.loc[nw_df["Athlete Name"] == "ZOU, Kai"]
# Out:
#          City    Year       Sport   Discipline Athlete Name  NOC Gender  \
# 1145  Beijing  2008.0  gymnastics  Artistic G.     ZOU, Kai  CHN    Men
# 1151  Beijing  2008.0  gymnastics  Artistic G.     ZOU, Kai  CHN    Men
# 1179  Beijing  2008.0  gymnastics  Artistic G.     ZOU, Kai  CHN    Men
#
#                  Event Event Gender Medal
# 1145   floor exercises            M  gold
# 1151    horizontal bar            M  gold
# 1179  team competition            M  gold

# %%
# combining both data files



def preprocess(filename = "data/olympics_medal_data_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  return df

def preprocess_2008(filename="data/olympics_medal_data_1896_2008.csv"):
  print(f"Preprocessing {filename} ...\n")
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  df.City = df.City.astype("string")
  df.Year = df.Year.astype(int)
  df.Sport = df.Sport.astype("string")
  df.Discipline = df.Discipline.astype("string")
  df["Athlete Name"] = df["Athlete Name"].astype("string")
  df.NOC = df.NOC.astype("string")
  df.Gender = df.Gender.astype("category")
  df.Event = df.Event.astype("string")
  df['Event Gender'] = df['Event Gender'].astype("category")
  medal_order = ["Bronze", "Silver", "Gold"]
  df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

  return df

df = preprocess()
new_df = preprocess_2008()
combined_df = pd.concat([df, new_df])
combined_df.dtypes
# Out:
# Preprocessing data/olympics_medal_data_1896_2004.csv ...
#
# Preprocessing data/olympics_medal_data_1896_2008.csv ...
# Year                     int64
# City            string[python]
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender          category
# Medal                 category
# dtype: object

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29216 entries, 0 to 2052
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          29216 non-null  int64
#  1   City          29216 non-null  string
#  2   Sport         29216 non-null  string
#  3   Discipline    29216 non-null  string
#  4   Athlete Name  29216 non-null  string
#  5   NOC           29216 non-null  string
#  6   Gender        29216 non-null  category
#  7   Event         29216 non-null  string
#  8   Event Gender  29216 non-null  category
#  9   Medal         29216 non-null  category
# dtypes: category(3), int64(1), string(6)
# memory usage: 1.9 MB

# %%
### Plotting Data

# %%
import matplotlib.pyplot as plt

# %%
# plot first olympic games
first_games = combined_df[combined_df.Year == 1896]

# %%
(first_games
 .Sport
 .value_counts()
 .plot(kind='bar')
)
# Out:
# <Axes: xlabel='Sport'>

# %%
# horizontal bar
(first_games
 .Sport
 .value_counts()
 .plot(kind='barh')
)
# Out:
# <Axes: ylabel='Sport'>

# %%
# ploting using Seabord

import seaborn as sns

# 2008 games
games_2008 = combined_df[combined_df.Year == 2008]

plt.figure(figsize=(5,3))
plt.title("Medals from the 2008 games")
sns.countplot(data=games_2008,
              x='Medal',
              order=["Gold", "Silver", "Bronze"],
              hue='Gender',
              palette='bwr'
             )
# Out:
# <Axes: title={'center': 'Medals from the 2008 games'}, xlabel='Medal', ylabel='count'>

# %% [markdown]
# ### Working with GroupBy

# %%
# 100m and 200m events in 2008 olympics
sprints = combined_df[(combined_df.Year == 2008) & ((combined_df.Event == '100m') | (combined_df.Event == '200m'))]
sprints
# Out:
#      Year     City      Sport Discipline              Athlete Name  NOC  \
# 388  2008  Beijing  athletics  athletics               DIX, Walter  USA
# 389  2008  Beijing  athletics  athletics               BOLT, Usain  JAM
# 390  2008  Beijing  athletics  athletics         THOMPSON, Richard  TRI
# 391  2008  Beijing  athletics  athletics        FRASER, Shelly-ann  JAM
# 392  2008  Beijing  athletics  athletics          SIMPSON, Sherone  JAM
# 393  2008  Beijing  athletics  athletics           STEWART, Kerron  JAM
# 406  2008  Beijing  athletics  athletics               DIX, Walter  USA
# 407  2008  Beijing  athletics  athletics               BOLT, Usain  JAM
# 408  2008  Beijing  athletics  athletics           CRAWFORD, Shawn  USA
# 409  2008  Beijing  athletics  athletics           STEWART, Kerron  JAM
# 410  2008  Beijing  athletics  athletics  CAMPBELL-BROWN, Veronica  JAM
# 411  2008  Beijing  athletics  athletics            FELIX, Allyson  USA
#
# ...

# %%
sp = sprints.groupby(['NOC', 'Gender', 'Event'])
sp
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_20312\1729970244.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sp = sprints.groupby(['NOC', 'Gender', 'Event'])

# %%
type(combined_df.groupby("Year"))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
combined_df.groupby("Year").count()
# Out:
#       City  Sport  Discipline  Athlete Name   NOC  Gender  Event  \
# Year
# 1896   151    151         151           151   151     151    151
# 1900   512    512         512           512   512     512    512
# 1904   470    470         470           470   470     470    470
# 1908   804    804         804           804   804     804    804
# 1912   885    885         885           885   885     885    885
# 1920  1298   1298        1298          1298  1298    1298   1298
# 1924   884    884         884           884   884     884    884
# 1928   710    710         710           710   710     710    710
# 1932   615    615         615           615   615     615    615
# 1936   875    875         875           875   875     875    875
# 1948   814    814         814           814   814     814    814
# 1952   889    889         889           889   889     889    889
# 1956   885    885         885           885   885     885    885
# ...

# %%
# include null value in count
combined_df.groupby("Year").size()
# Out:
# Year
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# dtype: int64

# %%
# DataFrameGroupBy has two components -> key and value(DataFrame)
for group_key, group_value in combined_df.groupby('Year'):
    print(group_key)
    print(group_value)
# Out:
# 1896
#      Year    City       Sport     Discipline          Athlete Name  NOC  \
# 0    1896  Athens     cycling  cycling track         FLAMENG, Léon  FRA
# 1    1896  Athens     cycling  cycling track    KOLETTIS, Georgios  GRE
# 2    1896  Athens   athletics      athletics         LANE, Francis  USA
# 3    1896  Athens   athletics      athletics      SZOKOLYI, Alajos  HUN
# 4    1896  Athens   athletics      athletics         BURKE, Thomas  USA
# ..    ...     ...         ...            ...                   ...  ...
# 146  1896  Athens   athletics      athletics       CONNOLLY, James  USA
# 147  1896  Athens   athletics      athletics    TUFFERI, Alexandre  FRA
# 148  1896  Athens  gymnastics    artistic g.  WEINGÄRTNER, Hermann  GER
# 149  1896  Athens  gymnastics    artistic g.        SCHUMANN, Carl  GER
# 150  1896  Athens  gymnastics    artistic g.         ZUTTER, Louis  SUI
#
#     Gender        Event Event Gender   Medal
# 0      Men        100km            M    Gold
# ...

# %%
combined_df.groupby(['Year','NOC'])['Medal'].count()
# Out:
# Year  NOC
# 1896  AUS      2
#       AUT      5
#       DEN      6
#       FRA     11
#       GBR      7
#             ...
# 2008  USA    315
#       UZB      6
#       VEN      1
#       VIE      1
#       ZIM      4
# Name: Medal, Length: 1072, dtype: int64

# %%
combined_df.groupby(['NOC'])['Year'].agg(['min', 'max', 'count'])
# Out:
#       min   max  count
# NOC
# AFG  2008  2008      1
# AHO  1988  1988      1
# ALG  1984  2008     14
# ANZ  1908  1912     29
# ARG  1924  2008    239
# ..    ...   ...    ...
# VIE  2000  2008      2
# YUG  1924  2000    435
# ZAM  1984  1996      2
# ZIM  1980  2008     23
# ZZX  1896  1904     48
#
# [138 rows x 3 columns]

# %% [markdown]
# ### Reshaping data: Stacking, Unstacking and MultiIndex

# %%
sprints = combined_df[(combined_df.Year == 2008) & ( (combined_df.Event == '100m') | (combined_df.Event == '200m'))]
sprints
# Out:
#      Year     City      Sport Discipline              Athlete Name  NOC  \
# 388  2008  Beijing  athletics  athletics               DIX, Walter  USA
# 389  2008  Beijing  athletics  athletics               BOLT, Usain  JAM
# 390  2008  Beijing  athletics  athletics         THOMPSON, Richard  TRI
# 391  2008  Beijing  athletics  athletics        FRASER, Shelly-ann  JAM
# 392  2008  Beijing  athletics  athletics          SIMPSON, Sherone  JAM
# 393  2008  Beijing  athletics  athletics           STEWART, Kerron  JAM
# 406  2008  Beijing  athletics  athletics               DIX, Walter  USA
# 407  2008  Beijing  athletics  athletics               BOLT, Usain  JAM
# 408  2008  Beijing  athletics  athletics           CRAWFORD, Shawn  USA
# 409  2008  Beijing  athletics  athletics           STEWART, Kerron  JAM
# 410  2008  Beijing  athletics  athletics  CAMPBELL-BROWN, Veronica  JAM
# 411  2008  Beijing  athletics  athletics            FELIX, Allyson  USA
#
# ...

# %%
sp = sprints.groupby(['NOC','Gender','Event']).size()
sp
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_20312\1800058050.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sp = sprints.groupby(['NOC','Gender','Event']).size()
# NOC  Gender  Event
# JAM  Men     100m     1
#              200m     1
#      Women   100m     3
#              200m     2
# TRI  Men     100m     1
#              200m     0
#      Women   100m     0
#              200m     0
# USA  Men     100m     1
#              200m     2
#      Women   100m     0
#              200m     1
# dtype: int64

# %%
(sp
 .unstack('Gender', fill_value=0)
 .unstack('Event', fill_value=0)
)
# Out:
# Gender  Men      Women
# Event  100m 200m  100m 200m
# NOC
# JAM       1    1     3    2
# TRI       1    0     0    0
# USA       1    2     0    1

# %%
# same as above but using level
sprints_table = sp.unstack(level=1, fill_value=0).unstack(level=1, fill_value=0)
sprints_table
# Out:
# Gender  Men      Women
# Event  100m 200m  100m 200m
# NOC
# JAM       1    1     3    2
# TRI       1    0     0    0
# USA       1    2     0    1

# %%
sprints_NOC = sprints_table.stack("Gender")
sprints_NOC
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_20312\3568702013.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   sprints_NOC = sprints_table.stack("Gender")
# Event       100m  200m
# NOC Gender
# JAM Men        1     1
#     Women      3     2
# TRI Men        1     0
#     Women      0     0
# USA Men        1     2
#     Women      0     1

# %%
#multi index
sprints_NOC.index
# Out:
# MultiIndex([('JAM',   'Men'),
#             ('JAM', 'Women'),
#             ('TRI',   'Men'),
#             ('TRI', 'Women'),
#             ('USA',   'Men'),
#             ('USA', 'Women')],
#            names=['NOC', 'Gender'])

# %%
sprints_NOC.loc[('JAM',   'Men'), :]
# Out:
# Event
# 100m    1
# 200m    1
# Name: (JAM, Men), dtype: int64

# %% [markdown]
# ### Problem  1
#
# plot the number of gold medals won by the USA male and female Olympians throughout the history of the Olympics?

# %%
usa_gold = combined_df[(combined_df.NOC == 'USA') & (combined_df.Medal == 'Gold')]

# %%
usa_gold.groupby(['Year', 'Gender']).size().unstack('Gender').plot(kind='line', color=['pink', 'blue'])
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_20312\1281612549.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   usa_gold.groupby(['Year', 'Gender']).size().unstack('Gender').plot(kind='line', color=['pink', 'blue'])
# <Axes: xlabel='Year'>

# %% [markdown]
# ### Problem  2
#
# plot the 5 Olympians who have won the most gold medals from the dataset (1896 to 2008). When there is a tie, consider the number of silver medals, then bronze medals

# %%
combined_df.groupby(['Athlete Name','Medal']).size()
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_20312\2275770920.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   combined_df.groupby(['Athlete Name','Medal']).size()
# Athlete Name           Medal
# AABYE, Edgar           Bronze    0
#                        Silver    0
#                        Gold      1
# AALTONEN, Arvo Ossian  Bronze    2
#                        Silver    0
#                                 ..
# ÖSTMO, Ole             Silver    2
#                        Gold      0
# ÖSTRAND, Per-Olof      Bronze    1
#                        Silver    0
#                        Gold      0
# Length: 64239, dtype: int64

# %%
(combined_df.groupby(['Athlete Name','Medal'])
.size()
.unstack('Medal', fill_value=0)
)
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_20312\1848037942.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (combined_df.groupby(['Athlete Name','Medal'])
# Medal                      Bronze  Silver  Gold
# Athlete Name
# AABYE, Edgar                    0       0     1
# AALTONEN, Arvo Ossian           2       0     0
# AALTONEN, Paavo Johannes        2       0     3
# AAMODT, Ragnhild                0       0     1
# AANING, Alf Lied                0       1     0
# ...                           ...     ...   ...
# ÖSTERVOLD, Jan Olsen            0       0     1
# ÖSTERVOLD, Kristian Olsen       0       0     1
# ÖSTERVOLD, Ole Olsen            0       0     1
# ÖSTMO, Ole                      2       2     0
# ÖSTRAND, Per-Olof               1       0     0
#
# [21413 rows x 3 columns]

# %%
(combined_df.groupby(['Athlete Name','Medal'])
.size()
.unstack('Medal', fill_value=0)
.sort_values(['Gold', 'Silver', 'Bronze'], ascending=False)
)
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_20312\1966962856.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (combined_df.groupby(['Athlete Name','Medal'])
# Medal                Bronze  Silver  Gold
# Athlete Name
# PHELPS, Michael           2       0    14
# LATYNINA, Larisa          4       5     9
# NURMI, Paavo              0       3     9
# SPITZ, Mark               1       1     9
# LEWIS, Carl               0       1     9
# ...                     ...     ...   ...
# ZYCH, Boguslaw            1       0     0
# ZÄHRINGER, Klaus          1       0     0
# ZÜHLKE, Steffen           1       0     0
# ÖRSTED, Hans-Henrik       1       0     0
# ÖSTRAND, Per-Olof         1       0     0
#
# [21413 rows x 3 columns]

# %%
(combined_df.groupby(['Athlete Name','Medal'])
.size()
.unstack('Medal', fill_value=0)
.sort_values(['Gold', 'Silver', 'Bronze'], ascending=False)[['Gold', 'Silver', 'Bronze']]
)
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_20312\2932132817.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (combined_df.groupby(['Athlete Name','Medal'])
# Medal                Gold  Silver  Bronze
# Athlete Name
# PHELPS, Michael        14       0       2
# LATYNINA, Larisa        9       5       4
# NURMI, Paavo            9       3       0
# SPITZ, Mark             9       1       1
# LEWIS, Carl             9       1       0
# ...                   ...     ...     ...
# ZYCH, Boguslaw          0       0       1
# ZÄHRINGER, Klaus        0       0       1
# ZÜHLKE, Steffen         0       0       1
# ÖRSTED, Hans-Henrik     0       0       1
# ÖSTRAND, Per-Olof       0       0       1
#
# [21413 rows x 3 columns]

# %%
(combined_df.groupby(['Athlete Name','Medal'])
.size()
.unstack('Medal', fill_value=0)
.sort_values(['Gold', 'Silver', 'Bronze'], ascending=False)[['Gold', 'Silver', 'Bronze']]
.head(5)
.plot(kind='bar')
)
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_20312\737058678.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (combined_df.groupby(['Athlete Name','Medal'])
# <Axes: xlabel='Athlete Name'>
